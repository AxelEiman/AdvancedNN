# %%
# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %%
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures

dataset = Planetoid(root='data/Planetoid', name='Cora', transform=NormalizeFeatures())

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
#print(f'Number of nodes: {data.num_nodes}')
#print(f'Number of edges: {data.num_edges}')
#print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
#print(f'Number of training nodes: {data.train_mask.sum()}')
#print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
#print(f'Has isolated nodes: {data.has_isolated_nodes()}')
#print(f'Has self-loops: {data.has_self_loops()}')
#print(f'Is undirected: {data.is_undirected()}')
# Out:
# Dataset: Cora():
# ======================
# Number of graphs: 1
# Number of features: 1433
# Number of classes: 7
#
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])
# ===========================================================================================================

# %% [markdown]
# **1 a)** From the Planetoid Cora dataset, extract the number of nodes that are in the training set, validation set, and test set. Discuss briefly the implications for supervised
# versus semi-supervised learning.

# %%
print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Number of validation nodes: {data.val_mask.sum()}')
print(f'Number of test nodes: {data.test_mask.sum()}')
# Out:
# Number of training nodes: 140
# Number of validation nodes: 500
# Number of test nodes: 1000

# %% [markdown]
# We dont have very many labeled nodes for training, so supervised learning will struggle. Only being able to train on 140 noded means that it will be hard to learn in a way that generalizes over the whole data set. We do however have quite a number of nodes in validation, so semi-supervised learning could be able to produce better results by inferring labels to the rest of the data set????

# %% [markdown]
# **b)** Train both a standard dense network using supervised learning and network using the convolution from equation 1 using semi-supervised learning
#
# and
#
# **c)** In both cases, implement 'early stopping' using the validation set, i.e. the training should evaluate against the validation set to stop training when this fails to improve.

# %%
# First a standard dense network
import torch
from torch.nn import Linear
import torch.nn.functional as F
import numpy as np
import copy


class MLP(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(12345)
        self.lin1 = Linear(dataset.num_features, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x):
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return x

mlp_model = MLP(hidden_channels=16)
print(mlp_model)
# Out:
# MLP(
#   (lin1): Linear(in_features=1433, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=7, bias=True)
# )

# %%
mlp_model = MLP(hidden_channels=16)
criterion = torch.nn.CrossEntropyLoss()  # Define loss criterion.
optimizer = torch.optim.Adam(mlp_model.parameters(), lr=0.01, weight_decay=5e-4)  # Define optimizer.


def mlp_train():
    mlp_model.train()
    optimizer.zero_grad()
    out = mlp_model(data.x)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss

def mlp_test(model):
    model.eval()
    out = model(data.x)
    pred = out.argmax(dim=1)
    test_correct = pred[data.test_mask] == data.y[data.test_mask]
    test_acc = int(test_correct.sum()) / int(data.test_mask.sum())
    return test_acc

def mlp_validate(saved_models, accuracies):
    test_acc = mlp_test(mlp_model)#, data.val_mask)
    accuracies = np.append(accuracies[1:], test_acc)

    model_copy = copy.deepcopy(mlp_model)
    saved_models = np.append(saved_models[1:], model_copy)
    
    return saved_models, accuracies


patience = 20
s_accuracies = np.zeros(patience)
s_models = np.empty(patience)
s_models[:] = np.NaN

for epoch in range(1, 201):
    loss = mlp_train()
    s_models, s_accuracies = mlp_validate(s_models, s_accuracies)
    #print(f'Saved Models: {s_models}')
    #print(f'Accuracies: {s_accuracies}')
    #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
    if s_accuracies[0] == np.max(s_accuracies):
        best_mlp = s_models[0]
        break

# %%
test_acc = mlp_test(best_mlp)
print(f'Test Accuracy (best MLP): {test_acc:.4f}')
# Out:
# Test Accuracy (best MLP): 0.5720

# %%
best_mlp.eval()

out = best_mlp(data.x)#, data.edge_index - Only nodes?
visualize(out, color=data.y)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
#  **Now for the network using graph convolutions**

# %%
from torch_geometric.nn import GCNConv


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(1234567)
        self.conv1 = GCNConv(dataset.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x

gcn_model = GCN(hidden_channels=16)
print(gcn_model)
# Out:
# GCN(
#   (conv1): GCNConv(1433, 16)
#   (conv2): GCNConv(16, 7)
# )

# %%
gcn_model = GCN(hidden_channels=16)
optimizer = torch.optim.Adam(gcn_model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def gcn_train():
      gcn_model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = gcn_model(data.x, data.edge_index)  # Perform a single forward pass.
      loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss

def gcn_test(model):
      model.eval()
      out = model(data.x, data.edge_index)
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
      test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
      return test_acc

def gcn_validate(saved_models, accuracies):
    test_acc = gcn_test(gcn_model)
    accuracies = np.append(accuracies[1:], test_acc)

    model_copy = copy.deepcopy(gcn_model)
    saved_models = np.append(saved_models[1:], model_copy)
    
    return saved_models, accuracies

patience = 20
s_accuracies = np.zeros(patience)
s_models = np.empty(patience)
s_models[:] = np.NaN

for epoch in range(1, 201):
      loss = gcn_train()
      s_models, s_accuracies = gcn_validate(s_models, s_accuracies)
      print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}
# Epoch: 080, Loss: 0.7796
# Epoch: 081, Loss: 0.7219
# Epoch: 082, Loss: 0.7344
# Epoch: 083, Loss: 0.7615
# Epoch: 084, Loss: 0.7080
# Epoch: 085, Loss: 0.6787
# Epoch: 086, Loss: 0.6604
# Epoch: 087, Loss: 0.7130
# Epoch: 088, Loss: 0.6547
# Epoch: 089, Loss: 0.6875
# Epoch: 090, Loss: 0.6553
# Epoch: 091, Loss: 0.6415
# Epoch: 092, Loss: 0.6317
# Epoch: 093, Loss: 0.6714
# Epoch: 094, Loss: 0.6224
# Epoch: 095, Loss: 0.6383
# Epoch: 096, Loss: 0.5889
# Epoch: 097, Loss: 0.6571
# Epoch: 098, Loss: 0.6018
# Epoch: 099, Loss: 0.5607
# Epoch: 100, Loss: 0.5876
# Epoch: 101, Loss: 0.5489
# Epoch: 102, Loss: 0.5667
# Epoch: 103, Loss: 0.5753
# Epoch: 104, Loss: 0.5653
# Epoch: 105, Loss: 0.5317
# Epoch: 106, Loss: 0.5568
# Epoch: 107, Loss: 0.5516
# Epoch: 108, Loss: 0.5286
# Epoch: 109, Loss: 0.5174
# Epoch: 110, Loss: 0.5637
# Epoch: 111, Loss: 0.5750
# Epoch: 112, Loss: 0.5392
# Epoch: 113, Loss: 0.4894
# Epoch: 114, Loss: 0.5268
# Epoch: 115, Loss: 0.4872
# Epoch: 116, Loss: 0.4889
# Epoch: 117, Loss: 0.4847
# Epoch: 118, Loss: 0.5021

# %%
test_acc = gcn_test(best_gcn)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Test Accuracy: 0.8130

# %%
gcn_model.eval()

out = gcn_model(data.x, data.edge_index)
visualize(out, color=data.y)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# **2)** Try to outperform the results from (1) using one of the more advances algorithms such as the graph attention network, from eqn. 3-4. Try to optimize performance, varying the number of heads (for GAT), different pooling layers, dropout, etc. (Extensive hyper-parameter tuning however is not asked for.)
#
# It may not be that easy to improve the results from (1) much (see Cora Benchmark), the main objective here is to show that you have tried.

# %%
from torch_geometric.nn import GATConv


class GAT(torch.nn.Module):
    def __init__(self, hidden_channels, heads):
        super().__init__()
        torch.manual_seed(1234567)
        self.conv1 = GATConv(dataset.num_features, hidden_channels, heads, concat=False)
        self.conv2 = GATConv(hidden_channels, dataset.num_classes, 1)

    def forward(self, x, edge_index):
        x = F.dropout(x, p=0.6, training=self.training)
        x = self.conv1(x, edge_index)
        x = F.elu(x)
        x = F.dropout(x, p=0.6, training=self.training)
        x = self.conv2(x, edge_index)
        return x

gat_model = GAT(hidden_channels=18, heads=8)
print(gat_model)

optimizer = torch.optim.Adam(gat_model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def gat_train():
    gat_model.train()
    out = gat_model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss

def gat_test(model, mask):
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)
    correct = pred[mask] == data.y[mask]
    acc = int(correct.sum()) / int(mask.sum())
    model_copy = copy.deepcopy(model)
    return acc, model_copy


patience = 100
s_accuracies = np.zeros(patience)
s_models = np.empty(patience)
s_models[:] = np.NaN
max_iter = 1001

for epoch in range(1, max_iter):
    loss = gat_train()
    val_acc, model_copy = gat_test(gat_model, data.val_mask)
    test_acc, _ = gat_test(gat_model, data.test_mask)

    s_models = np.append(s_models[1:], model_copy)
    s_accuracies = np.append(s_accuracies[1:], val_acc)

    if s_accuracies[0] == np.max(s_accuracies) or epoch==max_iter-1:
        best_gat = s_models[np.argmax(s_accuracies)]
        break

    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_acc:.4f}, Test: {test_acc:.4f}')
# Epoch: 129, Loss: 0.7277, Val: 0.5500, Test: 0.5560
# Epoch: 130, Loss: 0.8898, Val: 0.5420, Test: 0.5510
# Epoch: 131, Loss: 0.7943, Val: 0.5460, Test: 0.5500
# Epoch: 132, Loss: 0.8623, Val: 0.5420, Test: 0.5470
# Epoch: 133, Loss: 1.2647, Val: 0.5380, Test: 0.5420
# Epoch: 134, Loss: 1.3530, Val: 0.5360, Test: 0.5400
# Epoch: 135, Loss: 0.9548, Val: 0.5360, Test: 0.5440
# Epoch: 136, Loss: 1.2254, Val: 0.5460, Test: 0.5480
# Epoch: 137, Loss: 1.2992, Val: 0.5540, Test: 0.5560
# Epoch: 138, Loss: 1.1566, Val: 0.5540, Test: 0.5560
# Epoch: 139, Loss: 1.0228, Val: 0.5660, Test: 0.5590
# Epoch: 140, Loss: 0.7202, Val: 0.5740, Test: 0.5670
# Epoch: 141, Loss: 0.8065, Val: 0.5800, Test: 0.5730
# Epoch: 142, Loss: 0.9948, Val: 0.5760, Test: 0.5780
# Epoch: 143, Loss: 0.7896, Val: 0.5700, Test: 0.5790
# Epoch: 144, Loss: 1.0764, Val: 0.5760, Test: 0.5820
# Epoch: 145, Loss: 1.3258, Val: 0.5700, Test: 0.5840
# Epoch: 146, Loss: 0.8378, Val: 0.5660, Test: 0.5790
# Best GAT acc: 0.779

# %% [markdown]
# # Dataset 2
# - Divide the dataset 80/20 into a training set and a test set. (If you want to, use a partition of the training set for validation.)
# - Design a graph neural network with the objective to optimize the accuracy on the test set. Make sure to make use of the edge weights.

# %%
data = torch.load('graph_list_2022.pt')

# %%
# THIS IS PROBABLY IRRELEVANT NOW
import random


shuffled_data = random.sample(data, len(data)) # Returns new shuffled list

train_sz = int(0.6*len(data))
val_sz = int(0.8*len(data))

train_data = shuffled_data[0:train_sz]
val_data = shuffled_data[train_sz:val_sz]
test_data = shuffled_data[val_sz:]

print(data[0:3])
train_x = np.array(([graph.x for graph in train_data]))
train_edge_i = np.array([graph.edge_index for graph in train_data])
train_edge_w = np.array([graph.edge_attr for graph in train_data])
train_y = np.array([graph.y for graph in train_data])
print(train_x)
# Out:
# [Data(x=[6, 4], edge_index=[2, 30], edge_attr=[30, 1], y=[1, 4]), Data(x=[11, 4], edge_index=[2, 110], edge_attr=[110, 1], y=[1, 4]), Data(x=[7, 4], edge_index=[2, 42], edge_attr=[42, 1], y=[1, 4])]
# [tensor([[0.0000, 1.0000, 0.1429, 0.0000],
#          [1.0000, 0.0000, 0.1429, 0.4286],
#          [0.0000, 1.0000, 0.1429, 0.5714],
#          [0.0000, 1.0000, 0.2857, 0.4286],
#          [1.0000, 0.0000, 0.2857, 0.5714],
#          [0.0000, 1.0000, 0.4286, 0.0000],
#          [1.0000, 0.0000, 0.4286, 0.1429],
#          [0.0000, 1.0000, 0.5714, 0.1429],
#          [0.0000, 1.0000, 0.5714, 0.4286],
#          [0.0000, 1.0000, 0.7143, 0.5714]])
#  tensor([[1.0000, 0.0000, 0.0000, 0.8571],
#          [1.0000, 0.0000, 0.1429, 0.7143],
#          [0.0000, 1.0000, 0.7143, 0.0000],
#          [1.0000, 0.0000, 0.7143, 0.1429],
#          [0.0000, 1.0000, 0.8571, 0.1429]])
#  tensor([[1.0000, 0.0000, 0.4286, 0.1429],
#          [0.0000, 1.0000, 0.4286, 0.2857],
#          [0.0000, 1.0000, 0.5714, 0.1429],
#          [1.0000, 0.0000, 0.5714, 0.2857],
#          [0.0000, 1.0000, 0.7143, 0.8571],
#          [0.0000, 1.0000, 0.8571, 1.0000],
#          [1.0000, 0.0000, 1.0000, 0.1429]]) ...
#  tensor([[0.0000, 1.0000, 0.1429, 0.0000],
#          [1.0000, 0.0000, 0.1429, 0.1429],
#          [0.0000, 1.0000, 0.2857, 0.1429],
#          [0.0000, 1.0000, 0.4286, 0.5714],
#          [0.0000, 1.0000, 0.5714, 0.7143]])
#  tensor([[0.0000, 1.0000, 0.1429, 0.8571],
#          [0.0000, 1.0000, 0.2857, 0.1429],
#          [0.0000, 1.0000, 0.2857, 1.0000],
#          [0.0000, 1.0000, 0.4286, 0.0000],
#          [1.0000, 0.0000, 0.4286, 0.1429]])
#  tensor([[1.0000, 0.0000, 0.0000, 0.8571],
#          [0.0000, 1.0000, 0.2857, 0.7143],
#          [0.0000, 1.0000, 0.4286, 0.5714],
#          [0.0000, 1.0000, 0.4286, 0.8571],
#          [0.0000, 1.0000, 0.5714, 0.1429],
#          [0.0000, 1.0000, 0.5714, 0.4286],
#          [0.0000, 1.0000, 0.5714, 0.7143],
#          [0.0000, 1.0000, 0.7143, 0.0000],
#          [1.0000, 0.0000, 0.7143, 0.1429],
#          [0.0000, 1.0000, 0.8571, 0.1429]])]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:15: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   train_x = np.array(([graph.x for graph in train_data]))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_x = np.array(([graph.x for graph in train_data]))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:16: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   train_edge_i = np.array([graph.edge_index for graph in train_data])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:16: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_edge_i = np.array([graph.edge_index for graph in train_data])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:17: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   train_edge_w = np.array([graph.edge_attr for graph in train_data])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_edge_w = np.array([graph.edge_attr for graph in train_data])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:18: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   train_y = np.array([graph.y for graph in train_data])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16516\34705802.py:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_y = np.array([graph.y for graph in train_data])

# %%
from sklearn.model_selection import train_test_split
import random

random.shuffle(data)

cutoff = int(0.8*len(data))
train_data = data[:cutoff]
test_data = data[cutoff:]

print(f'Number of training graphs: {len(train_data)}')
print(f'Number of test graphs: {len(test_data)}')
# Out:
# Number of training graphs: 4000
# Number of test graphs: 1000

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader =  DataLoader(test_data, batch_size=64, shuffle=False)

for step, data_enum in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data_enum.num_graphs}')
    print(data_enum)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[486, 4], edge_index=[2, 3918], edge_attr=[3918, 1], y=[64, 4], batch=[486], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[448, 4], edge_index=[2, 3206], edge_attr=[3206, 1], y=[64, 4], batch=[448], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[460, 4], edge_index=[2, 3386], edge_attr=[3386, 1], y=[64, 4], batch=[460], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[467, 4], edge_index=[2, 3402], edge_attr=[3402, 1], y=[64, 4], batch=[467], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[477, 4], edge_index=[2, 3504], edge_attr=[3504, 1], y=[64, 4], batch=[477], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[500, 4], edge_index=[2, 4020], edge_attr=[4020, 1], y=[64, 4], batch=[500], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[503, 4], edge_index=[2, 3962], edge_attr=[3962, 1], y=[64, 4], batch=[503], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[506, 4], edge_index=[2, 3932], edge_attr=[3932, 1], y=[64, 4], batch=[506], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[503, 4], edge_index=[2, 4160], edge_attr=[4160, 1], y=[64, 4], batch=[503], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[513, 4], edge_index=[2, 4272], edge_attr=[4272, 1], y=[64, 4], batch=[513], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[506, 4], edge_index=[2, 3920], edge_attr=[3920, 1], y=[64, 4], batch=[506], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[541, 4], edge_index=[2, 4612], edge_attr=[4612, 1], y=[64, 4], batch=[541], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[439, 4], edge_index=[2, 2952], edge_attr=[2952, 1], y=[64, 4], batch=[439], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[481, 4], edge_index=[2, 3750], edge_attr=[3750, 1], y=[64, 4], batch=[481], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[480, 4], edge_index=[2, 3646], edge_attr=[3646, 1], y=[64, 4], batch=[480], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[485, 4], edge_index=[2, 3690], edge_attr=[3690, 1], y=[64, 4], batch=[485], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[506, 4], edge_index=[2, 4218], edge_attr=[4218, 1], y=[64, 4], batch=[506], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[535, 4], edge_index=[2, 4592], edge_attr=[4592, 1], y=[64, 4], batch=[535], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[481, 4], edge_index=[2, 3556], edge_attr=[3556, 1], y=[64, 4], batch=[481], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[486, 4], edge_index=[2, 3612], edge_attr=[3612, 1], y=[64, 4], batch=[486], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[504, 4], edge_index=[2, 4086], edge_attr=[4086, 1], y=[64, 4], batch=[504], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[468, 4], edge_index=[2, 3436], edge_attr=[3436, 1], y=[64, 4], batch=[468], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[494, 4], edge_index=[2, 3908], edge_attr=[3908, 1], y=[64, 4], batch=[494], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[533, 4], edge_index=[2, 4444], edge_attr=[4444, 1], y=[64, 4], batch=[533], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[479, 4], edge_index=[2, 3494], edge_attr=[3494, 1], y=[64, 4], batch=[479], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[519, 4], edge_index=[2, 4118], edge_attr=[4118, 1], y=[64, 4], batch=[519], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[541, 4], edge_index=[2, 4516], edge_attr=[4516, 1], y=[64, 4], batch=[541], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[504, 4], edge_index=[2, 4038], edge_attr=[4038, 1], y=[64, 4], batch=[504], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[477, 4], edge_index=[2, 3550], edge_attr=[3550, 1], y=[64, 4], batch=[477], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[503, 4], edge_index=[2, 3908], edge_attr=[3908, 1], y=[64, 4], batch=[503], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[453, 4], edge_index=[2, 3428], edge_attr=[3428, 1], y=[64, 4], batch=[453], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[516, 4], edge_index=[2, 4114], edge_attr=[4114, 1], y=[64, 4], batch=[516], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[474, 4], edge_index=[2, 3616], edge_attr=[3616, 1], y=[64, 4], batch=[474], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[467, 4], edge_index=[2, 3472], edge_attr=[3472, 1], y=[64, 4], batch=[467], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[502, 4], edge_index=[2, 4028], edge_attr=[4028, 1], y=[64, 4], batch=[502], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[476, 4], edge_index=[2, 3620], edge_attr=[3620, 1], y=[64, 4], batch=[476], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[533, 4], edge_index=[2, 4524], edge_attr=[4524, 1], y=[64, 4], batch=[533], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[514, 4], edge_index=[2, 4252], edge_attr=[4252, 1], y=[64, 4], batch=[514], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[485, 4], edge_index=[2, 3700], edge_attr=[3700, 1], y=[64, 4], batch=[485], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[509, 4], edge_index=[2, 4244], edge_attr=[4244, 1], y=[64, 4], batch=[509], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[535, 4], edge_index=[2, 4648], edge_attr=[4648, 1], y=[64, 4], batch=[535], ptr=[65])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[492, 4], edge_index=[2, 3824], edge_attr=[3824, 1], y=[64, 4], batch=[492], ptr=[65])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[516, 4], edge_index=[2, 4238], edge_attr=[4238, 1], y=[64, 4], batch=[516], ptr=[65])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[539, 4], edge_index=[2, 4570], edge_attr=[4570, 1], y=[64, 4], batch=[539], ptr=[65])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[528, 4], edge_index=[2, 4408], edge_attr=[4408, 1], y=[64, 4], batch=[528], ptr=[65])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[492, 4], edge_index=[2, 3762], edge_attr=[3762, 1], y=[64, 4], batch=[492], ptr=[65])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[498, 4], edge_index=[2, 4088], edge_attr=[4088, 1], y=[64, 4], batch=[498], ptr=[65])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[471, 4], edge_index=[2, 3440], edge_attr=[3440, 1], y=[64, 4], batch=[471], ptr=[65])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[531, 4], edge_index=[2, 4336], edge_attr=[4336, 1], y=[64, 4], batch=[531], ptr=[65])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[497, 4], edge_index=[2, 3804], edge_attr=[3804, 1], y=[64, 4], batch=[497], ptr=[65])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[506, 4], edge_index=[2, 3992], edge_attr=[3992, 1], y=[64, 4], batch=[506], ptr=[65])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[483, 4], edge_index=[2, 3678], edge_attr=[3678, 1], y=[64, 4], batch=[483], ptr=[65])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[474, 4], edge_index=[2, 3532], edge_attr=[3532, 1], y=[64, 4], batch=[474], ptr=[65])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[512, 4], edge_index=[2, 4146], edge_attr=[4146, 1], y=[64, 4], batch=[512], ptr=[65])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[465, 4], edge_index=[2, 3456], edge_attr=[3456, 1], y=[64, 4], batch=[465], ptr=[65])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[501, 4], edge_index=[2, 4052], edge_attr=[4052, 1], y=[64, 4], batch=[501], ptr=[65])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[473, 4], edge_index=[2, 3394], edge_attr=[3394, 1], y=[64, 4], batch=[473], ptr=[65])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[497, 4], edge_index=[2, 3914], edge_attr=[3914, 1], y=[64, 4], batch=[497], ptr=[65])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[515, 4], edge_index=[2, 4260], edge_attr=[4260, 1], y=[64, 4], batch=[515], ptr=[65])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[569, 4], edge_index=[2, 5244], edge_attr=[5244, 1], y=[64, 4], batch=[569], ptr=[65])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[479, 4], edge_index=[2, 3582], edge_attr=[3582, 1], y=[64, 4], batch=[479], ptr=[65])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[482, 4], edge_index=[2, 3706], edge_attr=[3706, 1], y=[64, 4], batch=[482], ptr=[65])
#
# Step 63:
# =======
# Number of graphs in the current batch: 32
# DataBatch(x=[247, 4], edge_index=[2, 1948], edge_attr=[1948, 1], y=[32, 4], batch=[247], ptr=[33])

# %%
# Out:
# 4

# %%
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(1234567)
        self.conv1 = GCNConv(data[0].x.size(dim=1), int(hidden_channels/2))
        self.conv2 = GCNConv(int(hidden_channels/2), hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, data[0].y.size(dim=1))

    def forward(self, x, edge_index, edge_attr, batch):
        x = self.conv1(x, edge_index, edge_weight=edge_attr)
        x = x.relu()
        x = self.conv2(x, edge_index, edge_weight=edge_attr)
        x = x.relu()
        x = self.conv3(x, edge_index, edge_weight=edge_attr)

        x = global_mean_pool(x, batch)
        
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

gcn_model = GCN(hidden_channels=64)
print(gcn_model)
# Out:
# GCN(
#   (conv1): GCNConv(4, 32)
#   (conv2): GCNConv(32, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
gcn_model = GCN(hidden_channels=64)

optimizer = torch.optim.Adam(gcn_model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()


def gcn_train():
      gcn_model.train()

      for data in train_loader:
            out = gcn_model(data.x, data.edge_index, data.edge_attr, data.batch)
            loss = criterion(out, data.y)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

      #optimizer.zero_grad()  # Clear gradients.
      #out = gcn_model(train_x, train_edge_i, train_edge_w)  # Perform a single forward pass.
      #loss = criterion(out, train_y)  # Compute the loss solely based on the training nodes.
      #loss.backward()  # Derive gradients.
      #optimizer.step()  # Update parameters based on gradients.
      return loss

def gcn_test(model, loader):
      model.eval()

      correct = 0
      for data in loader:
            #print(data)
            out = model(data.x, data.edge_index, data.edge_attr, data.batch)
            pred = out.argmax(dim=1)
            #print(pred)
            #print(data.y.argmax(dim=1))
            correct += int((pred == data.y.argmax(dim=1)).sum())
      
      return correct / len(loader.dataset)

      #out = model(data.x, data.edge_index)
      #pred = out.argmax(dim=1)  # Use the class with highest probability.
      #test_correct = pred[data.test_mask] == data.y[data.test_mask]  # Check against ground-truth labels.
      #test_acc = int(test_correct.sum()) / int(data.test_mask.sum())  # Derive ratio of correct predictions.
      #return test_acc

def gcn_validate(saved_models, accuracies):
    test_acc = gcn_test(gcn_model, test_loader)
    accuracies = np.append(accuracies[1:], test_acc)

    model_copy = copy.deepcopy(gcn_model)
    saved_models = np.append(saved_models[1:], model_copy)
    
    return saved_models, accuracies

patience = 50
s_accuracies = np.zeros(patience)
s_models = np.empty(patience)
s_models[:] = np.NaN

for epoch in range(1, 501):
      loss = gcn_train()
      s_models, s_accuracies = gcn_validate(s_models, s_accuracies)
      print(f'Epoch: {epoch:03d}, Loss: {loss:.4f},